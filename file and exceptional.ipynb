# %%
#1. Discuss the scenarios where multithreading is preferable to multiprocessing and scenarios where
multiprocessing is a better choice.

ANS = Multithreading vs Multiprocessing:

Multithreding:
    preferable scenarios
1. #i/0-bound tasks: 
    when tasks involve waiting for external resources . multithtreading is better.threads can wait without blocking
the entire process.
2. #shared memory:
    how tasks need to share data,multithreding is more efficient,as threads share the same memomry space.
3 #low overhead:
    creating threads is faster and uses less resources than creating process.
4 #GUI application:
    Multithreading is suitable for GUI apication,as it allows for reponsive UI updates while performing tasks.
    
    
    #MULTIPROCESSING:
PREFERABLE SCENARIOS:
    #PREFERABLE SCENARIOS:
1.#CPU-BOUND TASKS:
  When tasks are computationally intensive,multiprocessing is better.processes can utlize multiple CPU cores,improving overall performance.
2. #large data processing:
  when dealing with large datasets,multiprocessing can handle them more efficiently,as each process can work on a separate chunk
    of data.
3. #independent tasks:
  whwn tasks arendependent and dont require shared memory or communication,multiprocessing is a better choice.
4. #high-preformance computing:
  milyiprecessing is suitable for high-performance computing application,such as scientific simulation or data analysis,where parallel processing
    is crucial.

# %%
#2. Describe what a process pool is and how it helps in managing multiple processes efficiently


ANS =#Reuseable processes: 
A process pool creates a fixed number of worker processes that can be reused to excute multiple tasks,reducing the
overhead of creating and destroying processes.
2. # Task queue:
the prosesses pool manages a task queue,where tasks are submitted and executed by available worker processes.
3.#Load balancing:
The procesees pool distributes tasks across worker processes,ensuring that no single process is overloaded.
4.#synchronization:
The processes,eliminating the need for manual synchronization.
5.#Error handling:
The processes pool provides ,echanism for handling errors and exception raised by worker processes.
6#Efficient resource utilization:
by reusing worker processes and managing tasks efficiently,the process pool minimizes resources waste and improve overall sysytem 
utilization.
In pythan,the multiprocesssing module provide the pool class,which implements a process pool.you can create  pool with a specified
numberof worker processes and submit tasks to yhe pool using the apply_async or map_async methods.

# %%
# 3. Explain what multiprocessing is and why it is used in Python programs.

ANS = Multiprocessing is a technique where a program uses multiple processes to excute tasks concurrrntly,improving 
overall performance and efficiency.in pythan,multiprocessing is used to:
    1.#Utilize multiple CPU cores:
    By creating multiple process,pythan can take advantage of multiple CPU cores,improving performance for 
    computationally intensive tasks.
    2.#Overcome GIL limitation:
    pythans global intepreter lock(GIL) prevents true parallel eexecution of threads.multiprrocessing bypasses the GIL,allowing true paraallesim.
    3.#Improve responsiveness:
    Multiprocessing can improve the responsiveness of a program by executing time-consuming tasks in separte processes.
    4.#Enhance scalability:
    Multiprocessing enables pythan program to scale better for large datasets or high-performance computing application.
#common use cases gfor multiprocessing in pythan includes:
    1.Data processing and analysis
    2.scientific computing and simulations
    3.web scraping and crawling
    4.machine learning and AI
    5.High-performance computing

# %%
#4. Write a Python program using multithreading where one thread adds numbers to a list, and another
#thread removes numbers from the list. Implement a mechanism to avoid race conditions using
#threading.Lock.
import threading
import time

# Shared resource
numbers = []

# Lock to prevent race conditions
lock = threading.Lock()

def add_numbers():
    for i in range(10):
        time.sleep(1)  # Simulate some delay
        with lock:
            numbers.append(i)
            print(f"Added {i}, List: {numbers}")

def remove_numbers():
    for i in range(10):
        time.sleep(1.5)  # Simulate some delay
        with lock:
            if numbers:
                removed = numbers.pop(0)
                print(f"Removed {removed}, List: {numbers}")

# Create threads
thread1 = threading.Thread(target=add_numbers)
thread2 = threading.Thread(target=remove_numbers)

# Start threads
thread1.start()
thread2.start()

# Wait for threads to complete
thread1.join()
thread2.join()

print("Final List:", numbers)
# Out:
# Added 0, List: [0]
# Removed 0, List: []
# Added 1, List: [1]
# Added 2, List: [1, 2]
# Removed 1, List: [2]
# Added 3, List: [2, 3]
# Removed 2, List: [3]
# Added 4, List: [3, 4]
# Removed 3, List: [4]
# Added 5, List: [4, 5]
# Added 6, List: [4, 5, 6]
# Removed 4, List: [5, 6]
# Added 7, List: [5, 6, 7]
# Removed 5, List: [6, 7]
# Added 8, List: [6, 7, 8]
# Added 9, List: [6, 7, 8, 9]
# Removed 6, List: [7, 8, 9]
# Removed 7, List: [8, 9]
# Removed 8, List: [9]
# Removed 9, List: []
# Final List: []

# %%
#5. Describe the methods and tools available in Python for safely sharing data between threads and
#processes.

Python provides several methods and tools for safely sharing data between threads and processes:

Threads:

1. Locks (threading.Lock): Synchronize access to shared data.
2. RLocks (threading.RLock): Reentrant locks for nested access.
3. Semaphores (threading.Semaphore): Control access to shared resources.
4. Conditions (threading.Condition): Wait for specific conditions.
5. Queues (queue.Queue): Thread-safe queues for data exchange.

Processes:

1. Pipes (multiprocessing.Pipe): Communicate between processes.
2. Queues (multiprocessing.Queue): Process-safe queues for data exchange.
3. Shared Memory (multiprocessing.Value and multiprocessing.Array): Share memory between processes.
4. Managers (multiprocessing.Manager): Create shared data structures.

Additional Tools:

1. threading.Event: Synchronize threads using events.
2. threading.Barrier: Synchronize threads at a barrier.
3. concurrent.futures: High-level interface for parallelism.

When sharing data between threads or processes, consider:

1. Data ownership: Clearly define which thread or process owns the data.
2. Synchronization: Use locks or other synchronization primitives to protect shared data.
3. Data consistency: Ensure data remains consistent across threads or processes.
4. Deadlock avoidance: Design your synchronization strategy to avoid deadlocks.

# %%
#6. Discuss why it’s crucial to handle exceptions in concurrent programs and the techniques available for
#doing so.

ANS = 1. #uncaught exception can terminate the entire program:
         In a concurrent program, an uncaught exception in one threads or process can bring down the ebtire program
    leading to unexpected behavior or crashes.
    2.#Exception can be diffucult to debug:
    in a concurrent program,exception can be challenging to dubug due to the complexity of interaction between threads
    or processes.
    3.#Exception can lead to resource leaks:
    unhandled exception can cause resource leaks,such as unclosed files or netwwork connection,which can impact
    system performance.
#Techniques for handling exception in concurrent program:
    
    1.Try-except blocks:use try-except block to catch and handle exception with in individual or processes.
    2.Threads/process exception handlers:use threads or process exception handlers to catch and handle exception
    at the threads or process level.
    3.Global exception handlers:use global exception handlers to catch and handle exception that propagate up the 
    call stack.
    4.Asyncio and cuncurrent.future:use libaries like asyncio and concurrent.future,which provide built-in
    exception handling mechanisms.
    5.Logging and monitoring:Implement logging and monitoring to detect and diagnose exception in concurrent program.
    6.Fault-tolerant design:Design concurrent program with fault tolreance in mind,using techniques like redundancy
    and failovers.

# %%
#7. Create a program that uses a thread pool to calculate the factorial of numbers from 1 to 10 concurrently.
#Use concurrent.futures.ThreadPoolExecutor to manage the threads.


import concurrent.futures
import math

def calculate_factorial(n):
    return math.factorial(n)

def main():
    numbers = range(1, 11)
    with concurrent.futures.ThreadPoolExecutor() as executor:
        results = list(executor.map(calculate_factorial, numbers))
        for num, factorial in zip(numbers, results):
            print(f"Factorial of {num} is {factorial}")

if __name__ == "__main__":
    main()
# Out:
# Factorial of 1 is 1
# Factorial of 2 is 2
# Factorial of 3 is 6
# Factorial of 4 is 24
# Factorial of 5 is 120
# Factorial of 6 is 720
# Factorial of 7 is 5040
# Factorial of 8 is 40320
# Factorial of 9 is 362880
# Factorial of 10 is 3628800

# %%
#8. Create a Python program that uses multiprocessing.Pool to compute the square of numbers from 1 to 10 in
#parallel. Measure the time taken to perform this computation using a pool of different sizes (e.g., 2, 4, 8
#processes).


import multiprocessing
import time

def square(n):
    return n * n

def main():
    numbers = range(1, 11)
    pool_sizes = [2, 4, 8]

    for pool_size in pool_sizes:
        start_time = time.time()
        with multiprocessing.Pool(pool_size) as pool:
            results = pool.map(square, numbers)
        end_time = time.time()
        print(f"Pool size: {pool_size}, Time taken: {end_time - start_time} seconds")
        print(results)

if __name__ == "__main__":
    main()
# Out:
# Pool size: 2, Time taken: 0.02541971206665039 seconds
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# Pool size: 4, Time taken: 0.03732657432556152 seconds
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# Pool size: 8, Time taken: 0.06786513328552246 seconds
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
